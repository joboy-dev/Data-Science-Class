# %% [markdown]
# # Webscraping in Python
#
# ### Case Study: GoMarket Online Shopping Store

# %%
import requests
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# ## Functions

# %%
def get_title(card):
    '''Function to return all product titles'''
    
    if card.find('h2', class_='woo-loop-product__title') is None:
        title = ''
    else:
        title = card.find('h2', class_='woo-loop-product__title').text
        
    return title


def get_price(card):
    '''Function to return product prices'''
    
    if card.find('span', class_='price') is None:
        price = ''
    else:
        price = card.find('span', class_='price').text
        
    return price

def get_description(card):
    '''Function to return product description for all products'''
        
    if card.find('div', class_= 'woocommerce-product-details__short-description') is None:
        description = ''
    else:
        description = card.find('div', class_= 'woocommerce-product-details__short-description').text.strip()
        
    return description


def get_image(card):
    '''Function to return all product images'''
    
    image = card.find_all('img', class_='attachment-woocommerce_thumbnail')
        
    for index, img in enumerate(image):
        if image is None:
            image_url = ''
            
        image_url = img['src']
        return image_url


def make_request(url):
    '''Makes request to a url and returns a response content'''
    
    try:
        result = requests.get(url)  
        
        if result.status_code == 200:
            print('Request successful')
        else :
            print('Request unsuccessful')
    except Exception as e:
        print('An error occured')    
        
    return result.content

def dict_to_csv(data):
    '''Function to convert data into a csv file'''
    
    with open('groceries.csv', mode='w', newline='', encoding='utf-8') as csv_file:
        HEADERS = ['title', 'price', 'description', 'image']
        
        # write header
        csv_writer = csv.DictWriter(csv_file, fieldnames=HEADERS)
        csv_writer.writeheader()
        
        # write rows
        csv_writer.writerows(data)

# %% [markdown]
# ### Data Schema

# %%
groceries = list()

if __name__ == '__main__':
    for i in range(1, 6):
        # make request and store content in a variable
        content = make_request(f'https://www.gomarket.com.ng/product-category/groceries/page/{i}')
        
        # soup object
        soup = BeautifulSoup(content, 'html.parser')
        cards = soup.find('ul', class_='products columns-4').find_all('li')
        
        for card in cards:
            grocery = {
                'title': get_title(card),
                'price': get_price(card),
                'description': get_description(card),
                'image': get_image(card),
            }
            groceries.append(grocery)
            
        dict_to_csv(groceries)
# Out:
# Request successful
# Request successful
# Request successful
# Request successful
# Request successful

# %%
groceries
# Out:
# [{'title': 'Nosak Famili Vegetable Oil 2.5L -×6(in a cartoon)',
#   'price': '₦44,000.00₦49,500.00',
#   'description': 'Nosak Famili Vegetable Oil is 100% pure vegetable oil is a healthy alternative to adulterated oil. It has no additives and is cholesterol free. It’s hard to find unadulterated oil these days.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Nosak Famili Quality Palm Oil 2.5L -×6 (in a cartoon) cartoon)',
#   'price': '₦38,500.00₦49,500.00',
#   'description': 'Nosak Famili Palm Oil is your perfect choice for healthy cooking. It does not have any pungent smell, doesn’t stick to the tongue as noticed with adulterated oil and also gives your food an amazing flavor.\nREAD MORE',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': '
',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Golden Penny Spaghetti 500g',
#   'price': '₦796.95',
#   'description': '',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Indomie Super Pack onion flavor 120g',
#   'price': '₦17,999.00',
#   'description': '',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Ola Ola Yam Flour 2.2kg',
#   'price': '₦17,902.50',
#   'description': 'Pounded yam flour is used to make smooth dough called pounded yam. Pounded yam is a special delicacy and very popular food in West Africa. It is similar to mashed potatoes except that pounded yam is smoother, heavier and tastier. It is eaten with various types of stew or soup such as vegetable or egusi soup.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'KTC Pure Sunflower Oil 5L',
#   'price': '₦16,747.50',
#   'description': 'KTC Pure Sunflower Oil 5L',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Saffola Peeled Plum Tomators 400g',
#   'price': '₦1,155.00',
#   'description': '',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Pringles Texas BBQ Sace 40g',
#   'price': '₦952.88',
#   'description': '',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Heinze Ketchup 1.25kg',
#   'price': '₦6,352.50',
#   'description': 'Heinz Tomato Ketchup is a brand of ketchup produced by the H. J. Heinz Company. It is the highest-selling product the company has ever distributed. Besides glass bottles, Heinz ketchup comes in squeezable plastic containers and single-serving packets.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Lami Brown shawarma bread',
#   'price': '₦1,650.00',
#   'description': '',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Kelloggs Crunchy Nut 500g',
#   'price': '₦5,544.00',
#   'description': 'The Crunchy Nut range brings you an irresistible selection of truly delicious choices.\nGolden Flakes of Corn with Sugar, Peanuts and Honey.\nEnjoy as part of a varied & balanced diet and a healthy lifestyle.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Lamis White Flour 1kg',
#   'price': '₦2,541.00',
#   'description': 'We’ve got everything from flour, baking powder, baking soda, cake mix, cake decor, food essence, food colour, icing sugar and so much more.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Palm Oil 2.5L',
#   'price': '₦4,620.00',
#   'description': '2 Litre Fresh Palm Oil',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Sunola Soya Oil 1.9 litres',
#   'price': '₦5,775.00',
#   'description': 'A nutritious and completely balanced oil containing adequate nutrient levels. Made from Soya beans, Sunola Oil is healthy and does not control harmful cholesterols. Sunola soya oil is made from soya and is very pure, therefore healthy enough to be used in cooking for the whole family.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'De Rica Tomato Paste – 800g',
#   'price': '₦2,194.50',
#   'description': 'For tasty dishes\nDel Rico is a superior brand of tomato paste.\nIt provides vitamins and minerals all which make your meal more special.\nIt has a similar nutritional value of fresh tomatoes and GoMarket recommends it.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"},
#  {'title': 'Amoy Dark Soy Sauce-625ml',
#   'price': '₦4,042.50',
#   'description': 'Amoy dark soy sauce is wonderfully versatile. It enhances the sweetness and richness of your cooking. Add Amoy dark soy sauce when frying or grilling meat or veg to bring out the flavor.',
#   'image': "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20220%20220'%3E%3C/svg%3E"}]
